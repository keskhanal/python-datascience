# %% [markdown]
# # Python Basics

# %%
print("Hello vritjobs!")
# Out:
# Hello vritjobs!

# %%
# !python --version
# Out:
# Python 3.12.13

# %% [markdown]
# ## python comments

# %%
# Code to print hello world
# another comment
print('hello world!, single line comment')
# Out:
# hello world!, single line comment

# %%
"""
double
line
comment
"""
print("hello world!")
# Out:
# hello world!

# %%
# print your name
print("My name is Keshav")
# Out:
# My name is Keshav

# %%
# print "Kathmandu is the capital city of Nepal."
print("Kathmandu is the capital city of Nepal.")
# Out:
# Kathmandu is the capital city of Nepal.

# %%
print(1 + 2)
# Out:
# 3

# %%
print(False)
# Out:
# False

# %% [markdown]
# ## User input

# %%
input("Enter your name: ")
# Out:
# Enter your name: keshav
# 'keshav'

# %%
input("Enter your age: ")
# Out:
# Enter your age: 16
# '16'

# %% [markdown]
# # Variables

# %%
a = 4.2
b = 5
print(a)
print(b)
# Out:
# 4.2
# 5

# %%
a
b
# Out:
# 5

# %%
name = "raj"
print(name)
# Out:
# raj

# %%
salary = 200000
print(salary)
# Out:
# 200000

# %% [markdown]
# ## naming convention for variables
# good practice
# - name, student_name
#
# Bad practice
# - !name, 1salary, class, function

# %%
# get the name from user and print that name
name = input("Enter your name: ")
# Out:
# Enter your name: hari

# %%
print(name)
# Out:
# hari

# %%
# f string
print(f"My name is {name}.")
# Out:
# My name is hari.

# %%
print("My name is ", name, ".")
# Out:
# My name is  hari .

# %%
#get the age and print in this format 'My age is 50 years old.'
age = input("Enter your age: ")
print(f"My age is {age} years old.")
# Out:
# Enter your age: 10
# My age is 10 years old.

# %% [markdown]
# ## Data Types

# %%
# integer
age = 22
print(age)
type(age)
# Out:
# 22
# int

# %%
# float(32 bit)
salary = 200000.0345
print(salary)
type(salary)


# double(64 bit)
200000.0353531583
# Out:
# 200000.0345
# 200000.0353531583

# %%
salary = 200000.034556789
round(salary, 2)
# Out:
# 200000.03

# %%
# string
greet = "hello"
print(greet)
type(greet)
# Out:
# hello
# str

# %%
# boolean
is_tall = True
print(is_tall)
type(is_tall)
# Out:
# True
# bool

# %% [markdown]
# ### type conversion

# %%
type(salary)
# Out:
# float

# %%
int(salary)
# Out:
# 200000

# %%
str(age)
# Out:
# '22'

# %%
number = '100'
int(number)
# Out:
# 100

# %%
salary = input("what is your salary: ")
print(salary)
type(salary)
# Out:
# what is your salary: 10.1
# 10.1
# str

# %%
# get two numbers num1 and num2 from user and add(num1 + num2) them
num1 = int(input("enter 1st number: "))
num2 = int(input("enter 2nd number: "))

sum = num1 + num2
print(f"sum of num1 and num2: {sum}")
# Out:
# enter 1st number: 10
# enter 2nd number: 19
# sum of num1 and num2: 29

# %%
type(num1), type(num2)
# Out:
# (int, int)

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Arithemetic operators

# %%
# sum
1 + 2
# Out:
# 3

# %%
# subtraction
3-5
# Out:
# -2

# %%
# multiply
4*3
# Out:
# 12

# %%
# exponent
4**3
# Out:
# 64

# %%
# division
7/2
# Out:
# 3.5

# %%
# floor division
7//2
# Out:
# 3

# %%
# modulus
7 % 2
# Out:
# 1

# %%
# write program to add, subtract(num1 - num2), divide(num1/num2) and multply two number
num1 = 20
num2 = 5
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 25
# 15
# 100
# 4.0

# %% [markdown]
# ### comparision operators

# %%
4 > 5 # greater than
# Out:
# False

# %%
4 == 5
# Out:
# False

# %%
4<=5
# Out:
# True

# %%
5 >= 3
# Out:
# True

# %%
"hello" == "hello"
# Out:
# True

# %% [markdown]
# ## logical operators

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # write program to convert 97 fahrenheit to celsius
# # formula: c = (f - 32)*(5/9)

# %%
f = float(input("Enter fahrenheit: "))
# Out:
# Enter fahrenheit: 98

# %%
c = (f - 32)*(5/9)
c = round(c, 4)
print(f"celsius is {c}")
# Out:
# celsius is 36.6667
